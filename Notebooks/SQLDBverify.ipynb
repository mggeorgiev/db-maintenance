-- %% [markdown]
-- Verify version

-- %%
SELECT @@Version
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:02.062
-- <table><tr><th>(No column name)</th></tr><tr><td>Microsoft SQL Server 2019 (RTM-CU9) (KB5000642) - 15.0.4102.2 (X64)
-- 	Jan 25 2021 20:16:12
-- 	Copyright (C) 2019 Microsoft Corporation
-- 	Developer Edition (64-bit) on Linux (Ubuntu 18.04.5 LTS) &lt;X64&gt;</td></tr></table>

-- %% [markdown]
-- Determine the specific type of Azure SQL deployment, based on the number returned:
--
-- 1 = Personal or Desktop Engine
-- 2 = Standard
-- 3 = Enterprise
-- 4 = Express
-- 5 = SQL Database
-- 6 = SQL Data Warehouse
-- 8 = SQL Managed Instance

-- %%
SELECT SERVERPROPERTY('EngineEdition');
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.113
-- <table><tr><th>(No column name)</th></tr><tr><td>3</td></tr></table>

-- %% [markdown]
-- <span style="color: rgb(23, 23, 23); font-family: &quot;Segoe UI&quot;, SegoeUI, &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Verify the installation and the status of system databases and check system objects in the database.</span>

-- %%
SELECT * FROM sys.databases;
SELECT * FROM sys.objects;
-- Out:
-- (12 rows affected)
-- (130 rows affected)
-- Total execution time: 00:00:00.401
-- ...

-- %% [markdown]
-- <span style="color: rgb(23, 23, 23); font-family: &quot;Segoe UI&quot;, SegoeUI, &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">Verify that all schedulers are online and&nbsp; detecti the expected available CPUs</span>

-- %%
SELECT * FROM sys.dm_os_schedulers where STATUS = 'VISIBLE ONLINE';
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.088
-- ...

-- %% [markdown]
-- <span style="color: rgb(23, 23, 23); font-family: &quot;Segoe UI&quot;, SegoeUI, &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">As sys.dm_process_memory is not available check via:</span>

-- %%
SELECT * FROM sys.dm_user_db_resource_governance;
-- Out:
-- : Msg 208, Level 16, State 1, Line 1
-- Invalid object name 'sys.dm_user_db_resource_governance'.
-- Total execution time: 00:00:00.100

-- %% [markdown]
-- Verify available resources:

-- %%
SELECT * FROM sys.dm_os_job_object;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:03.552
-- <table><tr><th>cpu_rate</th><th>cpu_affinity_mask</th><th>cpu_affinity_group</th><th>memory_limit_mb</th><th>process_memory_limit_mb</th><th>workingset_limit_mb</th><th>non_sos_mem_gap_mb</th><th>low_mem_signal_threshold_mb</th><th>total_user_time</th><th>total_kernel_time</th><th>write_operation_count</th><th>read_operation_count</th><th>peak_process_memory_used_mb</th><th>peak_job_memory_used_mb</th><th>process_physical_affinity</th></tr><tr><td>100</td><td>32</td><td>0</td><td>7036</td><td>7036</td><td>NULL</td><td>1177</td><td>200</td><td>113750000</td><td>35156250</td><td>8999</td><td>11247</td><td>1333</td><td>1333</td><td>{{0,20}}</td></tr></table>

-- %% [markdown]
-- <span style="color: rgb(23, 23, 23); font-family: &quot;Segoe UI&quot;, SegoeUI, &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-size: 16px; background-color: rgb(255, 255, 255);">List active requests</span>

-- %%
SELECT * FROM sys.dm_exec_requests;
-- Out:
-- (57 rows affected)
-- Total execution time: 00:00:00.938
-- ...

-- %%
SELECT * FROM sys.database_files.max_size;
-- Out:
-- : Msg 40515, Level 15, State 1, Line 16
-- Reference to database and/or server name in 'sys.database_files.max_size' is not supported in this version of SQL Server.
-- Total execution time: 00:00:01.140
